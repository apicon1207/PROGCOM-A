# %%
#CHARLAS IDEAS TO REALITY

def mostrar_charla(opcion):
    if opcion == "1":
        print("\n--- PRIMERA CHARLA: Investigación transdisciplinaria ---")
        print("""
(Integración de diferentes disciplinas, integrar uno o más componentes de una disciplina no la disciplina en su totalidad)
La transdisciplinariedad es un enfoque para abordar preguntas complejas de relevancia social amplia mediante la integración
de diferentes disciplinas al nivel más alto. Esta integración lleva a trascender cualquier disciplina individual y da lugar
a nuevos marcos, conceptos y/o métodos. Un aspecto central de la transdisciplinariedad es la integración del conocimiento
de actores no académicos que están más cercanos a los temas o problemas en cuestión.

Enfoques transdisciplinarios:

1.	TD Trascendental
• Hacia la integración de todo el conocimiento humano.
• Lógica del tercer incluido. Dos cosas en una sola línea o realidad que son contradictorias, pero en otra realidad o en
otra línea si se podrá integrar, se podrá resolver (tercer incluido)
• Basarab Nicolescu, Tanya Augsburg

2.	TD enfocada en soluciones
• Enfrentar la complejidad para abordar problemas complejos
• Manfred A. Max-Neef, td-net (Swiss Academy of Sciences)

3.	TD como un "Tercer Espacio"
• Los estudios étnicos como transdisciplinariedad decolonial
• La experiencia de las personas pertenecientes a una etnia, la estudian. Cómo podemos trascender esas relaciones de poder
para darle espacio a esas ideas o formas de ver las cosas de otras etnias.
    "… los marcos de investigación basados en el deseo se centran en comprender la complejidad, la contradicción y la
    autodeterminación de las vidas vividas." Eve Tuck*
• Nelson Maldonado-Torres, Eve Tuck

Características:

⁃ Enfrentar la complejidad
⁃ Participación comunitaria
⁃ Justicia distributiva, procedimental, de reconocimiento, y justicia restaurativa o transformadora
⁃ Integración del conocimiento
⁃ Interacción y reflexión
""")

    elif opcion == "2":
        print("\n--- SEGUNDA CHARLA: Globalización y educación ---")
        print("""

1. El inglés abre puertas en la investigación
•	Contaron cómo el ICETEX apoya los semilleros y proyectos de investigación, lo que ayuda a que más estudiantes se metan
en el cuento.
•	Tatiana Gélvez compartió que hacer sus trabajos en inglés le ha abierto muchas más puertas y oportunidades.
•	Dijeron que el inglés es clave para investigar, compartir conocimientos y conectar con personas de otros países.
•	Además, el Ministerio de Ciencia también está metido en esto, apoyando a los grupos de investigación.

2. Lo local y lo global se complementan
•	Dijeron que lo global se enriquece de lo local y lo local de lo global, y eso lo llaman “glocal”.
•	Hablaron del ACOIL, que es cuando estudiantes de diferentes partes del mundo trabajan juntos por internet.
•	También explicaron cómo internacionalizar el currículo ayuda a mejorar la forma de enseñar y hace que estudiantes de acá
se conecten con los de otros países.

3. Conocimiento que transforma y genera oportunidades
•	María Francisca Cepeda habló de que Colombia necesita buscar formas más diversas de mover la economía, pensando en lo
que realmente se necesita.
•	Mencionaron a FLACSO, una facultad que trabaja en temas sociales desde una mirada latinoamericana.
•	Dijeron que la cooperación con otros países es clave y que el talento colombiano es muy buscado afuera, así que hay que
aprovechar esas oportunidades.
""")

    elif opcion == "3":
        print("\n--- TERCERA CHARLA: Investigación para la transformación ---")
        print("""
Defensa de la negatividad desde la ciencia.
Negatividad usada con cuidado es una herramienta para el cambio social.

¿POR QUÉ LO NEGATIVO LLAMA MÁS LA ATENCIÓN?

La neurociencia y la psicología, han demostrado que:

⁃	Reacción automática
Playa vs accidente - cuando no le prestas atención a los estímulos negativos la mente queda cucú.
La mente tiene una reacción automática a la negatividad, como un mensaje de urgencia.

⁃	Sesgo de negatividad
Consumimos más información negativa, el cerebro está atento a estímulos negativos.
No es que nos guste la negatividad, es que la elegimos por supervivencia.
Experimento Pratto y John (negro y rojo: malo, palabras negativas, amarillo y azul: bueno, palabras positivas) escribir
que se recuerda más, la respuesta fueron las palabras malas.

⁃	Utilidad evolutiva.

Características
• Características diagnósticas, nos ayudan a jugar con rapidez.
•	Es más memorable.
•	Es más creíble, y si es cierto, lo tendemos a considerar más útil.
""")
    else:
        print("Opción inválida.")



def main():
    print("Bienvenido a Ideas to Reality: Diálogos para la acción")
    print("Selecciona una charla para conocer más:")
    print("1. Investigación transdisciplinaria")
    print("2. Globalización y educación")
    print("3. Investigación para la transformación")

    seleccion = input("Ingresa el número de la charla (1-3): ")
    mostrar_charla(seleccion)

if __name__ == "__main__":
    main()
# Out:
# Bienvenido a Ideas to Reality: Diálogos para la acción
# Selecciona una charla para conocer más:
# 1. Investigación transdisciplinaria
# 2. Globalización y educación
# 3. Investigación para la transformación
# Ingresa el número de la charla (1-3): 1
#
# --- PRIMERA CHARLA: Investigación transdisciplinaria ---
#
# (Integración de diferentes disciplinas, integrar uno o más componentes de una disciplina no la disciplina en su totalidad)
# La transdisciplinariedad es un enfoque para abordar preguntas complejas de relevancia social amplia mediante la integración
# de diferentes disciplinas al nivel más alto. Esta integración lleva a trascender cualquier disciplina individual y da lugar
# a nuevos marcos, conceptos y/o métodos. Un aspecto central de la transdisciplinariedad es la integración del conocimiento
# de actores no académicos que están más cercanos a los temas o problemas en cuestión.
#
# Enfoques transdisciplinarios:
#
# 1.	TD Trascendental
# ...

# %% [markdown]
# #### CONFIRMACIÓN ASISTENCIA CHARLA 1
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### CONFIRMACIÓN ASISTENCIA CHARLA 2
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### CONFIRMACIÓN ASISTENCIA CHARLA 3
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # UNAB FEST
# # AYUDA EN LA CAMPAÑA DE ADOPCIÓN DE LA FUNDACIÓN SEATTLE
# ### Me incribí para ayudar en esta campaña de adopción y ayudé desde las 12 m hasta las 3 pm. Durante este  tiempo junto con un compañero ayudé a vender galletas y snacks para perritos, tambien ayudamos a cuidar y vestir a los perritos en adopción.
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### MEREZCO BONUS PORQUE DONÉ SANGRE Y CASI ME DESMAYO
#
# ##### ADJUNTO PRUEBAS
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
